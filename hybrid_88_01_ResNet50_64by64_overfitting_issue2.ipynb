# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q kaggle
# !mkdir ~/.kaggle

# %%
! cp "/content/drive/MyDrive/Colab Notebooks/Thesis/kaggle.json"  ~/.kaggle
! kaggle datasets download -d apollo2506/eurosat-dataset
! cp "/content/eurosat-dataset.zip" "/content/drive/MyDrive/Colab Notebooks/Thesis"
# Download the UC Merced Land Use Dataset
! kaggle datasets download -d apollo2506/landuse-scene-classification
! cp "/content/landuse-scene-classification.zip" "/content/drive/MyDrive/Colab Notebooks/Thesis"
# Out:
# Downloading eurosat-dataset.zip to /content
# 100% 2.04G/2.04G [01:06<00:00, 41.7MB/s]
# 100% 2.04G/2.04G [01:06<00:00, 33.1MB/s]
# Downloading landuse-scene-classification.zip to /content
# 100% 1.98G/1.98G [01:14<00:00, 40.1MB/s]
# 100% 1.98G/1.98G [01:14<00:00, 28.5MB/s]

# %%
! unzip -q "/content/drive/MyDrive/Colab Notebooks/Thesis/eurosat-dataset.zip"
! unzip -q "/content/drive/MyDrive/Colab Notebooks/Thesis/landuse-scene-classification.zip"
! unzip -q "/content/drive/MyDrive/Colab Notebooks/Thesis/NWPU-RESISC45.zip"
! unzip -q "/content/drive/MyDrive/Colab Notebooks/Thesis/PatternNet.zip"

# %%
import os
import shutil

# Define the paths to the datasets
eurosat_datasets_dir = "/content/EuroSAT"
ucmerced_datasets_dir = "/content/images"
resisc_datasets_dir = "/content/NWPU-RESISC45/NWPU-RESISC45"
patternnet_datasets_dir = "/content/content/PatternNet"

# Define the destination directories
ucmerced_dest_dir = "/content/FinalDirectory"

# Function to move images to the UC Merced dataset folder
def move_images(source_class, destination_class, dataset_dir):
    source_path = os.path.join(dataset_dir, source_class)
    destination_path = os.path.join(ucmerced_dest_dir, destination_class)

    if not os.path.exists(destination_path):
        os.makedirs(destination_path)

    for filename in os.listdir(source_path):
        source_file = os.path.join(source_path, filename)
        destination_file = os.path.join(destination_path, filename)

        # Check if the destination file already exists
        if os.path.exists(destination_file):
            # Handle duplicate file names
            destination_file = os.path.join(destination_path, f'{source_class}_{filename}')

        shutil.move(source_file, destination_file)

# Move images based on the provided instructions
move_images("AnnualCrop", "agricultural", eurosat_datasets_dir)
move_images("PermanentCrop", "agricultural", eurosat_datasets_dir)
move_images("Forest", "forest", eurosat_datasets_dir)
move_images("HerbaceousVegetation", "herbaceous_vegetation", eurosat_datasets_dir)
move_images("Highway", "freeway", eurosat_datasets_dir)
move_images("Industrial", "industrial", eurosat_datasets_dir)
move_images("Pasture", "pasture", eurosat_datasets_dir)
move_images("Residential", "residential", eurosat_datasets_dir)
move_images("River", "river", eurosat_datasets_dir)
move_images("SeaLake", "sealake", eurosat_datasets_dir)


move_images("agricultural", "agricultural", ucmerced_datasets_dir)
move_images("airplane", "airplane", ucmerced_datasets_dir)
move_images("baseballdiamond", "baseball_diamond", ucmerced_datasets_dir)
move_images("beach", "beach", ucmerced_datasets_dir)
move_images("buildings", "commercial", ucmerced_datasets_dir)
move_images("chaparral", "chaparral", ucmerced_datasets_dir)
move_images("denseresidential", "residential", ucmerced_datasets_dir)
move_images("forest", "forest", ucmerced_datasets_dir)
move_images("freeway", "freeway", ucmerced_datasets_dir)
move_images("golfcourse", "golf_course", ucmerced_datasets_dir)
move_images("harbor", "harbor", ucmerced_datasets_dir)
move_images("intersection", "intersection", ucmerced_datasets_dir)
move_images("mediumresidential", "residential", ucmerced_datasets_dir)
move_images("mobilehomepark", "mobile_home_park", ucmerced_datasets_dir)
move_images("overpass", "overpass", ucmerced_datasets_dir)
move_images("parkinglot", "parking_lot", ucmerced_datasets_dir)
move_images("river", "river", ucmerced_datasets_dir)
move_images("runway", "runway", ucmerced_datasets_dir)
move_images("sparseresidential", "residential", ucmerced_datasets_dir)
move_images("storagetanks", "storage_tanks", ucmerced_datasets_dir)
move_images("tenniscourt", "tennis_court", ucmerced_datasets_dir)


move_images("airplane", "airplane", resisc_datasets_dir)
move_images("airport", "airport", resisc_datasets_dir)
move_images("baseball_diamond", "baseball_diamond", resisc_datasets_dir)
move_images("basketball_court", "basketball_court", resisc_datasets_dir)
move_images("beach", "beach", resisc_datasets_dir)
move_images("bridge", "bridge", resisc_datasets_dir)
move_images("chaparral", "chaparral", resisc_datasets_dir)
move_images("church", "church", resisc_datasets_dir)
move_images("circular_farmland", "circular_farmland", resisc_datasets_dir)
move_images("cloud", "cloud", resisc_datasets_dir)
move_images("commercial_area", "commercial", resisc_datasets_dir)
move_images("dense_residential", "residential", resisc_datasets_dir)
move_images("desert", "desert", resisc_datasets_dir)
move_images("forest", "forest", resisc_datasets_dir)
move_images("freeway", "freeway", resisc_datasets_dir)
move_images("golf_course", "golf_course", resisc_datasets_dir)
move_images("ground_track_field", "ground_track_field", resisc_datasets_dir)
move_images("harbor", "harbor", resisc_datasets_dir)
move_images("industrial_area", "industrial", resisc_datasets_dir)
move_images("intersection", "intersection", resisc_datasets_dir)
move_images("island", "island", resisc_datasets_dir)
move_images("lake", "lake", resisc_datasets_dir)
move_images("meadow", "meadow", resisc_datasets_dir)
move_images("medium_residential", "residential", resisc_datasets_dir)
move_images("mobile_home_park", "mobile_home_park", resisc_datasets_dir)
move_images("mountain", "mountain", resisc_datasets_dir)
move_images("overpass", "overpass", resisc_datasets_dir)
move_images("palace", "palace", resisc_datasets_dir)
move_images("parking_lot", "parking_lot", resisc_datasets_dir)
move_images("railway", "railway", resisc_datasets_dir)
move_images("railway_station", "railway_station", resisc_datasets_dir)
move_images("rectangular_farmland", "rectangular_farmland", resisc_datasets_dir)
move_images("river", "river", resisc_datasets_dir)
move_images("roundabout", "roundabout", resisc_datasets_dir)
move_images("runway", "runway", resisc_datasets_dir)
move_images("sea_ice", "sea_ice", resisc_datasets_dir)
move_images("ship", "ship", resisc_datasets_dir)
move_images("snowberg", "snowberg", resisc_datasets_dir)
move_images("sparse_residential", "residential", resisc_datasets_dir)
move_images("stadium", "stadium", resisc_datasets_dir)
move_images("storage_tank", "storage_tanks", resisc_datasets_dir)
move_images("tennis_court", "tennis_court", resisc_datasets_dir)
move_images("terrace", "terrace", resisc_datasets_dir)
move_images("thermal_power_station", "thermal_power_station", resisc_datasets_dir)
move_images("wetland", "wetland", resisc_datasets_dir)

move_images("airplane", "airplane", patternnet_datasets_dir)
move_images("baseball_diamond", "baseball_diamond", patternnet_datasets_dir)
move_images("basketball_court", "basketball_court", patternnet_datasets_dir)
move_images("beach", "beach", patternnet_datasets_dir)
move_images("bridge", "bridge", patternnet_datasets_dir)
move_images("cemetery", "cemetery", patternnet_datasets_dir)
move_images("chaparral", "chaparral", patternnet_datasets_dir)
move_images("christmas_tree_farm", "christmas_tree_farm", patternnet_datasets_dir)
move_images("closed_road", "closed_road", patternnet_datasets_dir)
move_images("coastal_mansion", "coastal_mansion", patternnet_datasets_dir)
move_images("crosswalk", "crosswalk", patternnet_datasets_dir)
move_images("dense_residential", "residential", patternnet_datasets_dir)
move_images("ferry_terminal", "ferry_terminal", patternnet_datasets_dir)
move_images("football_field", "football_field", patternnet_datasets_dir)
move_images("forest", "forest", patternnet_datasets_dir)
move_images("freeway", "freeway", patternnet_datasets_dir)
move_images("golf_course", "golf_course", patternnet_datasets_dir)
move_images("harbor", "harbor", patternnet_datasets_dir)
move_images("intersection", "intersection", patternnet_datasets_dir)
move_images("mobile_home_park", "mobile_home_park", patternnet_datasets_dir)
move_images("nursing_home", "nursing_home", patternnet_datasets_dir)
move_images("oil_gas_field", "oil_gas_field", patternnet_datasets_dir)
move_images("oil_well", "oil_well", patternnet_datasets_dir)
move_images("overpass", "overpass", patternnet_datasets_dir)
move_images("parking_lot", "parking_lot", patternnet_datasets_dir)
move_images("parking_space", "parking_space", patternnet_datasets_dir)
move_images("railway", "railway", patternnet_datasets_dir)
move_images("river", "river", patternnet_datasets_dir)
move_images("runway", "runway", patternnet_datasets_dir)
move_images("runway_marking", "runway_marking", patternnet_datasets_dir)
move_images("shipping_yard", "shipping_yard", patternnet_datasets_dir)
move_images("solar_panel", "solar_panel", patternnet_datasets_dir)
move_images("sparse_residential", "residential", patternnet_datasets_dir)
move_images("storage_tanks", "storage_tanks", patternnet_datasets_dir)
move_images("swimming_pool", "swimming_pool", patternnet_datasets_dir)
move_images("tennis_court", "tennis_court", patternnet_datasets_dir)
move_images("transformer_station", "transformer_station", patternnet_datasets_dir)
move_images("wastewater_treatment_plant", "wastewater_treatment_plant", patternnet_datasets_dir)

# %%
datasets_dir =  "/content/FinalDirectory"

# %%
IMG_SIZE = 64
BATCH_SIZE = 32
epochs = 20

# %%
import tensorflow as tf
tf.random.set_seed(42)

train_data = tf.keras.preprocessing.image_dataset_from_directory(
    directory = datasets_dir,
    image_size = (IMG_SIZE, IMG_SIZE),
    label_mode = 'categorical',
    color_mode="rgb",
    batch_size = BATCH_SIZE,
    seed=42,
    shuffle = True,
    validation_split=0.2,
    subset="training"

).prefetch(buffer_size=tf.data.AUTOTUNE)


test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    directory = datasets_dir,
    image_size =  (IMG_SIZE, IMG_SIZE),
    label_mode = 'categorical',
    color_mode="rgb",
    batch_size = BATCH_SIZE,
    seed=42,
    shuffle = True,
    validation_split=0.2,
    subset="validation"

)
class_names = test_dataset.class_names
test_data = test_dataset.prefetch(buffer_size=tf.data.AUTOTUNE)
# test_data = test_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
class_names
# Out:
# Found 99400 files belonging to 64 classes.
# Using 79520 files for training.
# Found 99400 files belonging to 64 classes.
# Using 19880 files for validation.
# ['agricultural',
#  'airplane',
#  'airport',
#  'baseball_diamond',
#  'basketball_court',
#  'beach',
#  'bridge',
#  'cemetery',
#  'chaparral',
#  'christmas_tree_farm',
#  'church',
#  'circular_farmland',
#  'closed_road',
#  'cloud',
#  'coastal_mansion',
#  'commercial',
#  'crosswalk',
#  'desert',
#  'ferry_terminal',
#  'football_field',
#  'forest',
#  'freeway',
#  'golf_course',
#  'ground_track_field',
#  'harbor',
#  'herbaceous_vegetation',
#  'industrial',
#  'intersection',
#  'island',
#  'lake',
#  'meadow',
#  'mobile_home_park',
#  'mountain',
#  'nursing_home',
#  'oil_gas_field',
#  'oil_well',
#  'overpass',
#  'palace',
#  'parking_lot',
#  'parking_space',
#  'pasture',
#  'railway',
#  'railway_station',
#  'rectangular_farmland',
#  'residential',
#  'river',
#  'roundabout',
#  'runway',
#  'runway_marking',
#  'sea_ice',
#  'sealake',
#  'ship',
#  'shipping_yard',
#  'snowberg',
#  'solar_panel',
#  'stadium',
#  'storage_tanks',
#  'swimming_pool',
#  'tennis_court',
#  'terrace',
#  'thermal_power_station',
#  'transformer_station',
#  'wastewater_treatment_plant',
#  'wetland']

# %%
import tensorflow as tf

data_augmentation = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal",input_shape=(IMG_SIZE, IMG_SIZE, 3)),
  tf.keras.layers.experimental.preprocessing.RandomRotation(0.2),
  tf.keras.layers.experimental.preprocessing.RandomZoom(0.2),
  tf.keras.layers.experimental.preprocessing.RandomHeight(0.2),
  tf.keras.layers.experimental.preprocessing.RandomWidth(0.2)
], name ="data_augmentation")

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.figure(figsize=(10,10))

for image_batch,label_batch in train_data.take(1):
    for i in range(0,12):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        plt.title(class_names[np.argmax(label_batch[i])])
        plt.axis("off")

# %%
plt.figure(figsize=(10,10))
for image_batch,label_batch in train_data.take(1):
    augmented_image_batch = data_augmentation(image_batch)
    image_plt_len = len(image_batch) if len(image_batch) < 4 else 4
    for i in range(0, image_plt_len):
        plt.subplot(image_plt_len,2,2*i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        plt.title(class_names[np.argmax(label_batch[i])])
        plt.axis("off")
        plt.subplot(image_plt_len,2,2*i+2)
        img = augmented_image_batch[i]
        img = np.array(img, dtype=np.int32)
        plt.imshow(img)
        plt.title(f"augmented")
        plt.axis("off")

# %%
import tensorflow as tf

# Setup the base models and freeze their layers (this will extract features)
base_model1 = tf.keras.applications.EfficientNetB0(include_top=False)
base_model2 = tf.keras.applications.ResNet50(include_top=False)

base_model1.trainable = True  # Enable fine-tuning
base_model2.trainable = True  # Enable fine-tuning

# Fine-tune only the last N layers
fine_tune_at = 50
for layer in base_model1.layers[:-fine_tune_at]:
    layer.trainable = False

fine_tune_at = 20
for layer in base_model2.layers[:-fine_tune_at]:
    layer.trainable = False

# Setup model architecture with trainable top layers
inputs = tf.keras.layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3), name='input_layer')
x = data_augmentation(inputs)
x1 = base_model1(x, training=False)
x2 = base_model2(x, training=False)
x1 = tf.keras.layers.GlobalAveragePooling2D(name='global_avg_pooling_layer1')(x1)
x2 = tf.keras.layers.GlobalAveragePooling2D(name='global_avg_pooling_layer2')(x2)
x = tf.keras.layers.concatenate([x1, x2])


x = tf.keras.layers.Dropout(0.4)(x)  # Adjust dropout rate
x = tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Add dense layer with L2 regularization
x = tf.keras.layers.BatchNormalization()(x)  # Add batch normalization
outputs = tf.keras.layers.Dense(len(class_names), activation='softmax', name='output_layer')(x)
model = tf.keras.Model(inputs, outputs)

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),  # Adjust the learning rate
    metrics=['accuracy']
)

# Early stopping callback
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=5,
    restore_best_weights=True
)

# Learning rate schedule callback
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=3,
    min_lr=1e-7,
    verbose=1
)

model.summary()
tf.keras.utils.plot_model(
    model,
    to_file='model.png',
    dpi=96,
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 1s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_layer (InputLayer)    [(None, 64, 64, 3)]          0         []
#
#  data_augmentation (Sequent  (None, None, None, 3)        0         ['input_layer[0][0]']
#  ial)
#
#  efficientnetb0 (Functional  (None, None, None, 1280)     4049571   ['data_augmentation[0][0]']
#  )
#
#  resnet50 (Functional)       (None, None, None, 2048)     2358771   ['data_augmentation[0][0]']
#                                                           2
#
#  global_avg_pooling_layer1   (None, 1280)                 0         ['efficientnetb0[0][0]']
#  (GlobalAveragePooling2D)
#
#  global_avg_pooling_layer2   (None, 2048)                 0         ['resnet50[0][0]']
#  (GlobalAveragePooling2D)
#
#  concatenate (Concatenate)   (None, 3328)                 0         ['global_avg_pooling_layer1[0]
#                                                                     [0]',
#                                                                      'global_avg_pooling_layer2[0]
#                                                                     [0]']
#
#  dropout (Dropout)           (None, 3328)                 0         ['concatenate[0][0]']
#
#  dense (Dense)               (None, 256)                  852224    ['dropout[0][0]']
#
#  batch_normalization (Batch  (None, 256)                  1024      ['dense[0][0]']
#  Normalization)
#
#  output_layer (Dense)        (None, 64)                   16448     ['batch_normalization[0][0]']
#
# ==================================================================================================
# Total params: 28506979 (108.75 MB)
# Trainable params: 12327376 (47.03 MB)
# Non-trainable params: 16179603 (61.72 MB)
# __________________________________________________________________________________________________

# %%
# Train the model with the learning rate schedule
history = model.fit(
    train_data,
    epochs=epochs,
    steps_per_epoch=len(train_data),
    validation_data=test_data,
    validation_steps=len(test_data),
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/20
# 2485/2485 [==============================] - 295s 106ms/step - loss: 3.2675 - accuracy: 0.6988 - val_loss: 1.6181 - val_accuracy: 0.7967 - lr: 1.0000e-04
# Epoch 2/20
# 2485/2485 [==============================] - 178s 71ms/step - loss: 1.1819 - accuracy: 0.8107 - val_loss: 0.9715 - val_accuracy: 0.8144 - lr: 1.0000e-04
# Epoch 3/20
# 2485/2485 [==============================] - 176s 71ms/step - loss: 0.8058 - accuracy: 0.8317 - val_loss: 0.8146 - val_accuracy: 0.8202 - lr: 1.0000e-04
# Epoch 4/20
# 2485/2485 [==============================] - 177s 71ms/step - loss: 0.6809 - accuracy: 0.8450 - val_loss: 0.7540 - val_accuracy: 0.8257 - lr: 1.0000e-04
# Epoch 5/20
# 2485/2485 [==============================] - 177s 71ms/step - loss: 0.6172 - accuracy: 0.8554 - val_loss: 0.7446 - val_accuracy: 0.8252 - lr: 1.0000e-04
# Epoch 6/20
# 2485/2485 [==============================] - 177s 71ms/step - loss: 0.5791 - accuracy: 0.8639 - val_loss: 0.6472 - val_accuracy: 0.8503 - lr: 1.0000e-04
# Epoch 7/20
# 2485/2485 [==============================] - 177s 71ms/step - loss: 0.5393 - accuracy: 0.8735 - val_loss: 0.6591 - val_accuracy: 0.8478 - lr: 1.0000e-04
# Epoch 8/20
# 2485/2485 [==============================] - 178s 71ms/step - loss: 0.5225 - accuracy: 0.8755 - val_loss: 0.6645 - val_accuracy: 0.8480 - lr: 1.0000e-04
# Epoch 9/20
# 2485/2485 [==============================] - 175s 70ms/step - loss: 0.4998 - accuracy: 0.8819 - val_loss: 0.6397 - val_accuracy: 0.8480 - lr: 1.0000e-04
# Epoch 10/20
# 2485/2485 [==============================] - 176s 71ms/step - loss: 0.4807 - accuracy: 0.8868 - val_loss: 0.6940 - val_accuracy: 0.8399 - lr: 1.0000e-04
# Epoch 11/20
# 2485/2485 [==============================] - 177s 71ms/step - loss: 0.4678 - accuracy: 0.8900 - val_loss: 0.6083 - val_accuracy: 0.8572 - lr: 1.0000e-04
# Epoch 12/20
# 2485/2485 [==============================] - 176s 71ms/step - loss: 0.4509 - accuracy: 0.8944 - val_loss: 0.6782 - val_accuracy: 0.8430 - lr: 1.0000e-04
# Epoch 13/20
# 2485/2485 [==============================] - 176s 71ms/step - loss: 0.4344 - accuracy: 0.8980 - val_loss: 0.5975 - val_accuracy: 0.8619 - lr: 1.0000e-04
# Epoch 14/20
# 2485/2485 [==============================] - 177s 71ms/step - loss: 0.4205 - accuracy: 0.9005 - val_loss: 0.5729 - val_accuracy: 0.8659 - lr: 1.0000e-04
# Epoch 15/20
# 2485/2485 [==============================] - 176s 71ms/step - loss: 0.4132 - accuracy: 0.9026 - val_loss: 0.6045 - val_accuracy: 0.8603 - lr: 1.0000e-04
# Epoch 16/20
# 2485/2485 [==============================] - 176s 71ms/step - loss: 0.4027 - accuracy: 0.9059 - val_loss: 0.5772 - val_accuracy: 0.8677 - lr: 1.0000e-04
# Epoch 17/20
# 2485/2485 [==============================] - ETA: 0s - loss: 0.3959 - accuracy: 0.9077
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 2485/2485 [==============================] - 177s 71ms/step - loss: 0.3959 - accuracy: 0.9077 - val_loss: 0.6143 - val_accuracy: 0.8597 - lr: 1.0000e-04
# Epoch 18/20
# 2485/2485 [==============================] - 176s 71ms/step - loss: 0.3219 - accuracy: 0.9254 - val_loss: 0.5024 - val_accuracy: 0.8804 - lr: 2.0000e-05
# Epoch 19/20
# 2485/2485 [==============================] - 176s 71ms/step - loss: 0.2829 - accuracy: 0.9319 - val_loss: 0.4931 - val_accuracy: 0.8806 - lr: 2.0000e-05
# Epoch 20/20
# 2485/2485 [==============================] - 176s 71ms/step - loss: 0.2641 - accuracy: 0.9338 - val_loss: 0.4839 - val_accuracy: 0.8801 - lr: 2.0000e-05

# %%
# Evaluate the model on both training and testing sets
model.evaluate(train_data), model.evaluate(test_data)
# Out:
# 2485/2485 [==============================] - 91s 37ms/step - loss: 0.3685 - accuracy: 0.9067
# 622/622 [==============================] - 23s 37ms/step - loss: 0.4839 - accuracy: 0.8801
# ([0.36852139234542847, 0.9066901206970215],
#  [0.483929306268692, 0.8800804615020752])

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  plt.figure(figsize=(12,6))
  # Plot loss
  plt.subplot(1,2,1)
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.subplot(1,2,2)
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend()

# %%
plot_loss_curves(history)

# %%
from sklearn.metrics import classification_report

# Evaluate the model on the test set
y_true = np.array([])
y_pred = np.array([])
for x, y in test_data:
    y_true = np.concatenate([y_true, np.argmax(y, axis=-1)], axis=0)
    y_pred = np.concatenate([y_pred, np.argmax(model.predict(x), axis=-1)], axis=0)

# Display classification report
report = classification_report(y_true, y_pred, target_names=class_names)
print("Classification Report:\n", report)
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 3s 3s/step
# Classification Report:
#                              precision    recall  f1-score   support
#
#               agricultural       0.97      0.91      0.94      1256
#                   airplane       0.97      0.89      0.93       415
#                    airport       0.82      0.68      0.74       134
#           baseball_diamond       0.92      0.90      0.91       421
#           basketball_court       0.55      0.88      0.68       313
#                      beach       0.91      0.98      0.94       359
#                     bridge       0.91      0.96      0.93       297
#                   cemetery       0.70      0.97      0.81       177
#                  chaparral       0.92      0.99      0.95       424
#        christmas_tree_farm       0.94      1.00      0.97       149
#                     church       0.62      0.53      0.57       144
#          circular_farmland       0.99      0.84      0.91       149
#                closed_road       0.95      0.95      0.95       165
#                      cloud       1.00      0.82      0.90       145
#            coastal_mansion       0.72      0.97      0.83       159
#                 commercial       0.77      0.68      0.73       267
#                  crosswalk       0.92      0.98      0.95       148
#                     desert       0.83      0.86      0.85       153
#             ferry_terminal       0.71      0.79      0.75       152
#             football_field       0.91      0.88      0.90       181
#                     forest       0.92      0.93      0.93       972
#                    freeway       0.92      0.90      0.91       886
#                golf_course       0.98      0.79      0.88       411
#         ground_track_field       0.84      0.52      0.64       130
#                     harbor       0.87      0.96      0.91       360
#      herbaceous_vegetation       0.95      0.81      0.87       589
#                 industrial       0.94      0.87      0.91       637
#               intersection       0.89      0.90      0.89       405
#                     island       0.94      0.88      0.91       155
#                       lake       0.88      0.90      0.89       162
#                     meadow       0.85      0.78      0.82       130
#           mobile_home_park       0.92      0.86      0.89       349
#                   mountain       0.77      0.78      0.77       125
#               nursing_home       0.82      0.65      0.73       169
#              oil_gas_field       1.00      0.89      0.94       171
#                   oil_well       1.00      0.99      0.99       178
#                   overpass       0.88      0.95      0.91       394
#                     palace       0.56      0.63      0.59       134
#                parking_lot       0.83      0.98      0.89       391
#              parking_space       0.89      0.99      0.94       156
#                    pasture       0.98      0.91      0.94       400
#                    railway       0.74      0.93      0.82       271
#            railway_station       0.61      0.80      0.69       132
#       rectangular_farmland       0.74      0.77      0.76       136
#                residential       0.89      0.88      0.88      1613
#                      river       0.96      0.88      0.92       911
#                 roundabout       0.95      0.77      0.85       113
#                     runway       0.95      0.86      0.91       398
#             runway_marking       0.98      0.94      0.96       174
#                    sea_ice       0.94      0.96      0.95       149
#                    sealake       1.00      0.88      0.94       614
#                       ship       0.83      0.82      0.82       146
#              shipping_yard       0.98      0.98      0.98       175
#                   snowberg       0.90      0.97      0.94       152
#                solar_panel       0.74      0.99      0.85       149
#                    stadium       0.78      0.89      0.83       136
#              storage_tanks       0.87      0.91      0.89       390
#              swimming_pool       0.82      0.99      0.90       171
#               tennis_court       0.88      0.63      0.73       392
#                    terrace       0.55      0.90      0.68       132
#      thermal_power_station       0.85      0.61      0.71       132
#        transformer_station       0.70      0.93      0.80       164
# wastewater_treatment_plant       0.89      0.98      0.93       170
#                    wetland       0.80      0.74      0.77       148
#
#                   accuracy                           0.88     19880
#                  macro avg       0.86      0.87      0.86     19880
#               weighted avg       0.89      0.88      0.88     19880

# %%
import itertools
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix

# Our function needs a different name to sklearn's plot_confusion_matrix
def make_confusion_matrix(y_true, y_pred, classes=None, figsize=(10, 10), text_size=15, norm=False):

    # Create the confusion matrix for the selected classes
    conf_matrix = confusion_matrix(y_true, y_pred)

    # Select only the first 10 classes
    conf_matrix_subset = conf_matrix[:10, :10]

    # Print the sum of instances for each class
    print("Class counts:", np.sum(conf_matrix_subset, axis=1))

    # Normalize the confusion matrix if specified
    if norm:
        conf_matrix_norm = conf_matrix_subset.astype("float") / conf_matrix_subset.sum(axis=1)[:, np.newaxis]
    else:
        conf_matrix_norm = None

    n_classes = conf_matrix_subset.shape[0]

    # Plot the figure and make it pretty
    fig, ax = plt.subplots(figsize=figsize)
    cax = ax.matshow(conf_matrix_subset, cmap=plt.cm.Blues)  # colors will represent how 'correct' a class is, darker == better
    fig.colorbar(cax)

    # Are there a list of classes?
    if classes:
        labels = classes[:n_classes]
    else:
        labels = np.arange(n_classes)

    # Label the axes
    ax.set(
        title="Confusion Matrix",
        xlabel="Predicted label",
        ylabel="True label",
        xticks=np.arange(n_classes),  # create enough axis slots for each class
        yticks=np.arange(n_classes),
        xticklabels=labels,  # axes will be labeled with class names (if they exist) or ints
        yticklabels=labels,
    )

    # Make x-axis labels appear on bottom
    ax.tick_params(axis='x', labelrotation=90)
    ax.xaxis.set_label_position("bottom")
    ax.xaxis.tick_bottom()

    # Set the threshold for different colors
    threshold = (conf_matrix_subset.max() + conf_matrix_subset.min()) / 2.

    # Plot the text on each cell
    for i, j in itertools.product(range(conf_matrix_subset.shape[0]), range(conf_matrix_subset.shape[1])):
        if norm:
            plt.text(j, i, f"{conf_matrix_subset[i, j]} ({conf_matrix_norm[i, j]*100:.1f}%)",
                     horizontalalignment="center",
                     color="white" if conf_matrix_subset[i, j] > threshold else "black",
                     size=text_size)
        else:
            plt.text(j, i, f"{conf_matrix_subset[i, j]}",
                     horizontalalignment="center",
                     color="white" if conf_matrix_subset[i, j] > threshold else "black",
                     size=text_size)

# Assuming y_true and y_pred have been calculated
y_true_subset = y_true[y_true < 10]
y_pred_subset = y_pred[y_true < 10]

# Assuming class_names is defined
make_confusion_matrix(y_true_subset, y_pred_subset, classes=class_names[:32])
plt.show()
# Out:
# Class counts: [1147  383   93  390  279  354  284  177  421  149]

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(12,12))
for image_batch,label_batch in test_data.take(1):
    predictions = model.predict(image_batch)
    predictions = np.argmax(predictions, axis=-1)
    for i in range(0,len(predictions) if len(predictions)<12 else 12):
        plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint32"))
        true_class = class_names[np.argmax(label_batch[i])]
        predict_class = class_names[predictions[i]]
        title = f"""True: {true_class}\n Predict: {predict_class}"""
        plt.title(title, color='g' if true_class==predict_class else 'r')
        plt.axis("off")
# Out:
# 1/1 [==============================] - 0s 36ms/step
